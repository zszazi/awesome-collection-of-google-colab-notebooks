# %% [markdown]
# <a href="https://colab.research.google.com/github/saicodes/awesome-collection-of-google-colab-notebooks/blob/master/Emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #upload and find the emotion of the person in the pic

# %%
# !pip install paralleldots
# Out:
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/b3/5f/bb/2026be732da73d6f7ed664b08a496829cd7db51a19a773de47
# Successfully built paralleldots
# ...

# %%
import paralleldots
paralleldots.set_api_key("I aint giving you my API key get yours from ParallelDots")

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-18c8b8a7-d22b-4ae0-ac92-c0a8956d67ff" name="files[]" multiple disabled />
#      <output id="result-18c8b8a7-d22b-4ae0-ac92-c0a8956d67ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving angry-little-girl.jpg to angry-little-girl.jpg
# ...

# %%
CONTENT_IMAGE = "angry-little-girl.jpg"

# %%
path= "/content/"+CONTENT_IMAGE

# %%
print( paralleldots.facial_emotion( path ) )
# Out:
# {'facial_emotion': [{'tag': 'Angry', 'score': 0.9462360144}, {'tag': 'Sad', 'score': 0.011321798}, {'tag': 'Neutral', 'score': 0.0084884334}, {'tag': 'Surprise', 'score': 0.0084884334}, {'tag': 'Happy', 'score': 0.0084884334}, {'tag': 'Fear', 'score': 0.0084884334}, {'tag': 'Disgust', 'score': 0.0084884334}], 'code': 200}

# %%
result = paralleldots.facial_emotion( path )

# %%
print(result)
# Out:
# {'facial_emotion': [{'tag': 'Angry', 'score': 0.9462360144}, {'tag': 'Sad', 'score': 0.011321798}, {'tag': 'Neutral', 'score': 0.0084884334}, {'tag': 'Surprise', 'score': 0.0084884334}, {'tag': 'Happy', 'score': 0.0084884334}, {'tag': 'Fear', 'score': 0.0084884334}, {'tag': 'Disgust', 'score': 0.0084884334}], 'code': 200}

# %%
mood = result['facial_emotion'][0]['tag']

# %% [markdown]
# Printing only the most accurate emotion

# %%
print(mood)
# Out:
# Angry
